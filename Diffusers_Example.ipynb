# %% [markdown]
# <a href="https://colab.research.google.com/github/cagBRT/Diffusers/blob/main/Diffusers_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 45.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 89.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 65.7 MB/s eta 0:00:00
# ...

# %%
# !pip3 install accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 4.3 MB/s eta 0:00:00
# ...

# %%
# !pip install diffusers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 7.9 MB/s eta 0:00:00
# ...

# %%
import transformers

# %%
from diffusers import StableDiffusionPipeline, LMSDiscreteScheduler
from diffusers import StableDiffusionPipeline
from diffusers import DiffusionPipeline

# %%
model_id = "CompVis/ldm-text2im-large-256"

# %%
# load text input to diffusion pipeline
ldm = DiffusionPipeline.from_pretrained(model_id)
# Out:
# ...
# unet/diffusion_pytorch_model.safetensors not found
# ...
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# The config attributes {'timestep_values': None} were passed to DDIMScheduler, but are not expected and will be ignored. Please verify your scheduler_config.json configuration file.

# %%
# run inference (sample random noise and denoise)
prompt = "A butterfly resting on a flower"
images = ldm([prompt], num_inference_steps=50, eta=.3, guidance_scale=6)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %% [markdown]
# The model generates a large batch of images. <br>
# Then use mappping to estimate which of the images are the best match to the prompt.

# %%
images.images
# Out:
# [<PIL.Image.Image image mode=RGB size=256x256>]

# %%
images.images[0]
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
