# %% [markdown]
# <a href="https://colab.research.google.com/github/cagBRT/Diffusers/blob/main/Diffusers_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install the required packages

# %%
# !pip3 install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 20.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 29.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 59.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 61.4 MB/s eta 0:00:00
# ...

# %%
# !pip3 install accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.2/251.2 kB 4.6 MB/s eta 0:00:00
# ...

# %%
# !pip install diffusers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 9.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Import the necessary libraries

# %%
import transformers

# %%
from diffusers import StableDiffusionPipeline, LMSDiscreteScheduler
from diffusers import StableDiffusionPipeline
from diffusers import DiffusionPipeline

# %% [markdown]
# # Select a diffusion model

# %% [markdown]
# **Safety**<br>
# Please note that text-to-image models are known to at times produce harmful content. Please raise any concerns you may have.

# %% [markdown]
# This is a high-resolution text-to-image latent diffusion model

# %%
model_id = "CompVis/ldm-text2im-large-256"

# %%
# load text input to diffusion pipeline
ldm = DiffusionPipeline.from_pretrained(model_id)
# Out:
# ...
# bert/model.safetensors not found
# ...
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
# The config attributes {'timestep_values': None} were passed to DDIMScheduler, but are not expected and will be ignored. Please verify your scheduler_config.json configuration file.

# %% [markdown]
# Researchers have found 30 inference steps is a good starting point. <br>
# The guidance scale is the amount of influence the prompt has on the final image.

# %% [markdown]
# Prepare extra kwargs for the scheduler step, since not all schedulers have the same signature<br>
#
# eta (η) is only used with the DDIMScheduler, it will be ignored for other schedulers.<br>
#
# eta corresponds to η in DDIM paper: https://arxiv.org/abs/2010.02502 and should be between [0, 1]<br>

# %% [markdown]
# # Use the model to create an image based on a prompt

# %% [markdown]
# # Change the prompt

# %%
# run inference (sample random noise and denoise)
prompt = "A photo of a butterfly resting on a flower, 4k"
images = ldm([prompt], num_inference_steps=30, eta=.3, guidance_scale=3)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %% [markdown]
# The model generates a large batch of images. <br>
# Then uses mappping to estimate which of the images are the best match to the prompt.

# %%
images.images
# Out:
# [<PIL.Image.Image image mode=RGB size=256x256>]

# %%
images.images[0]
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
